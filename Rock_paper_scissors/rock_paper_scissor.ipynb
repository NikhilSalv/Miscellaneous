# %% [markdown]
# # ROCK PAPER SCISSOR
# > # Mac VS Windows

# %%
import random
from IPython.display import Image

# %%
outcomes = ["rock","paper","scissors"]

# %%
player1 = random.choice(outcomes)
if player1 == "rock":
    c = Image(filename="img/rock.jpg", width=300 , height=300)
elif player1 == "scissors":
    c = Image(filename="img/scissors.jpg", width=300 , height=300)
else:
    c= Image(filename="img/paper.jpg", width=300 , height=300)  
c
